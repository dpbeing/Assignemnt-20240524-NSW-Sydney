# %% [markdown]
# Connected to .venv (Python 3.9.6)

# %%
from read_data import read_csv
from transform_data import transform_data

def main():
    # Read data
    raw_data = read_csv('/Users/deep/Assignemnt-20240524-NSW-Sydney/data/member-data.csv')
    # Transform data
    transformed_data = transform_data(raw_data)
    print(transformed_data)
    
if __name__ == '__main__':  
    main()
# Out:
# [Employee(full_name='Rebbecca Didio', company='Brandt, Jonathan F Esq', birth_date='16/03/1989', age=34.0, salary='$330,949.20', salary_bucket='C', phone=381749123, mobile=458665290, email='rebbecca.didio@didio.com.au', address=Address(street='171 E 24th St', suburb='Leith', state='TAS', post_code=7315)), Employee(full_name='Stevie Hallo', company='Landrum Temporary Services', birth_date='17/08/1985', age=38.0, salary='$309,558.52', salary_bucket='C', phone=799973366, mobile=497622620, email='stevie.hallo@hotmail.com', address=Address(street='22222 Acoma St', suburb='Proston', state='QLD', post_code=4613)), Employee(full_name='Mariko Stayer', company='Inabinet, Macre Esq', birth_date='20/06/1993', age=30.0, salary='$539,508.37', salary_bucket='C', phone=855589019, mobile=427885282, email='mariko_stayer@hotmail.com', address=Address(street='534 Schoenborn St #51', suburb='Hamel', state='WA', post_code=6215)), Employee(full_name='Gerardo Woodka', company='Morris Downing & Sherred', birth_date='14/05/1992', age=31.0, salary='$293,515.51', salary_bucket='C', phone=260444682, mobile=443795912, email='gerardo_woodka@hotmail.com', address=Address(street='69206 Jackson Ave', suburb='Talmalmo', state='NSW', post_code=2640)), Employee(full_name='Mayra Bena', company='Buelt, David L Esq', birth_date='20/08/1973', age=50.0, salary='$395,121.26', salary_bucket='C', phone=214556085, mobile=453666885, email='mayra.bena@gmail.com', address=Address(street='808 Glen Cove Ave', suburb='Lane Cove', state='NSW', post_code=1595)), Employee(full_name='Idella Scotland', company='Artesian Ice & Cold Storage Co', birth_date='30/01/1982', age=42.0, salary='$573,376.95', salary_bucket='C', phone=878681355, mobile=451966921, email='idella@hotmail.com', address=Address(street='373 Lafayette St', suburb='Cartmeticup', state='WA', post_code=6316)), Employee(full_name='Sherill Klar', company='Midway Hotel', birth_date='16/06/1988', age=35.0, salary='$896,019.77', salary_bucket='C', phone=865228931, mobile=427991688, email='sklar@hotmail.com', address=Address(street='87 Sylvan Ave', suburb='Nyamup', state='WA', post_code=6258)), Employee(full_name='Ena Desjardiws', company='Selsor, Robert J Esq', birth_date='11/02/1970', age=54.0, salary='$863,933.75', salary_bucket='C', phone=252269402, mobile=415961606, email='ena_desjardiws@desjardiws.com.au', address=Address(street='60562 Ky Rt 321', suburb='Bendick Murrell', state='NSW', post_code=2803)), Employee(full_name='Vince Siena', company='Vincent J Petti & Co', birth_date='12/05/1979', age=44.0, salary='$756,980.33', salary_bucket='C', phone=731849989, mobile=411732965, email='vince_siena@yahoo.com', address=Address(street='70 S 18th Pl', suburb='Purrawunda', state='QLD', post_code=4356)), Employee(full_name='Theron Jarding', company='Prentiss, Paul F Esq ', birth_date='29/10/2000', age=23.0, salary='$382,643.36', salary_bucket='C', phone=868904661, mobile=461862457, email='tjarding@hotmail.com', address=Address(street='8839 Ventura Blvd', suburb='Blanchetown', state='SA', post_code=5357)), Employee(full_name='Amira Chudej', company='Public Works Department', birth_date='05/02/1991', age=33.0, salary='$662,504.80', salary_bucket='C', phone=781353271, mobile=478867289, email='amira.chudej@chudej.net.au', address=Address(street='3684 N Wacker Dr', suburb='Rockside', state='QLD', post_code=4343)), Employee(full_name='Marica Tarbor', company='Prudential Lighting Corp', birth_date='20/03/1976', age=47.0, salary='$377,295.69', salary_bucket='C', phone=311746817, mobile=494982617, email='marica.tarbor@hotmail.com', address=Address(street='68828 S 32nd St #6', suburb='Rosegarland', state='TAS', post_code=7140)), Employee(full_name='Shawna Albrough', company='Wood, J Scott Esq', birth_date='09/09/1991', age=32.0, salary='$872,846.53', salary_bucket='C', phone=779776039, mobile=441255802, email='shawna.albrough@albrough.com.au', address=Address(street='43157 Cypress St', suburb='Ringwood', state='QLD', post_code=4343)), Em ...

# %%
import pytest
import pandas as pd
from src.transform_data import transform_data
from src.entity import Employee, Address

def test_transform_data():
    # Define a sample DataFrame
    data = {
        'FirstName': ['Deep' ,'Dan'],
        'LastName': ['Mehta', 'Smith'],
        'Company': ['Company Inc.', 'Another Co.'],
        'BirthDate': ['1980-01-01', '1990-02-02'],
        'Salary': [75000, 85000],
        'Address': ['123 Main St', '456 Another Rd'],
        'Suburb': ['Pymble', 'Other Suburb'],
        'State': ['NSW', 'VIC'],
        'Post': [12345, 67890],
        'Phone': [1234567890, 2345678901],
        'Mobile': [9876543210, 1987654320],
        'Email': ['deep_mehta@example.com', 'dan.smith@example.com']
    }
    
    df = pd.DataFrame(data)

    # Transform the data
    employees = transform_data(df)
    
    # Verify the data structure and content
    assert isinstance(employees, list)
    assert len(employees) == 2
    assert isinstance(employees[0], Employee)
    assert employees[0].full_name == 'Deep Mehta'
    assert employees[1].full_name == 'Dan Smith'
    assert employees[0].age == 44  # Assuming test is run in 2024
    assert employees[1].age == 34
    assert employees[0].salary == '$75,000.00'
    assert employees[1].salary == '$85,000.00'
    assert employees[0].salary_bucket == 'B'
    assert employees[1].salary_bucket == 'B'
    assert isinstance(employees[0].address, Address)
    assert employees[0].address.street == '123 Main St'
    assert employees[1].address.post_code == 67890

if __name__ == '__main__':
    pytest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Users/deep/Assignemnt-20240524-NSW-Sydney/tests/test_transform_data.py:3
#       1 import pytest
#       2 import pandas as pd
# ----> 3 from src.transform_data import transform_data
#       4 from src.entity import Employee, Address
#       6 def test_transform_data():
#       7     # Define a sample DataFrame
#
# ModuleNotFoundError: No module named 'src'

# %%
pytest src/tests/test_transformer.py
# Out:
#   Cell In[3], line 1
#     pytest src/tests/test_transformer.py
#            ^
# SyntaxError: invalid syntax
