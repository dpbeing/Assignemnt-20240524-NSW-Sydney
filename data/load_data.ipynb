# %%
from read_data import read_csv
from transform_data import transform_data
from load_data import save_data_as_json
def main():
    # Read data
    print("Reading data from CSV...")
    raw_data = read_csv('/Users/deep/Assignemnt-20240524-NSW-Sydney/data/member-data.csv')
    # Transform data
    print("Transforming data...")
    transformed_data = transform_data(raw_data)
    print(transformed_data)
    # Save data to JSON
    print("Saving data to JSON file...")
    save_data_as_json(transformed_data,'/Users/deep/Assignemnt-20240524-NSW-Sydney/data/output-data.json')

    
if __name__ == '__main__':  
    main()
# Out:
# Reading data from CSV...
# Transforming data...
#                         Company   BirthDate       Salary  \
# 0        Brandt, Jonathan F Esq  16/03/1989  $330,949.20
# 1    Landrum Temporary Services  17/08/1985  $309,558.52
# 2           Inabinet, Macre Esq  20/06/1993  $539,508.37
# 3      Morris Downing & Sherred  14/05/1992  $293,515.51
# 4            Buelt, David L Esq  20/08/1973  $395,121.26
# ..                          ...         ...          ...
# 495   Antietam Cable Television  24/11/1993  $944,148.81
# 496           Lombardi Bros Inc  30/08/1996  $650,026.91
# 497       Nathaniel Electronics  15/02/2002  $748,067.54
# 498     Rodriguez, Joseph A Esq  04/03/1969  $452,163.08
# 499     Stilling, William J Esq         NaN  $781,936.12
#
#                                                Address      Suburb State  \
# 0    {'Street': '171 E 24th St', 'Suburb': 'Leith',...       Leith   TAS
# 1    {'Street': '22222 Acoma St', 'Suburb': 'Prosto...     Proston   QLD
# 2    {'Street': '534 Schoenborn St #51', 'Suburb': ...       Hamel    WA
# 3    {'Street': '69206 Jackson Ave', 'Suburb': 'Tal...    Talmalmo   NSW
# 4    {'Street': '808 Glen Cove Ave', 'Suburb': 'Lan...   Lane Cove   NSW
# ..                                                 ...         ...   ...
# 495  {'Street': '28465 Downey Ave #4238', 'Suburb':...   Barringun   QLD
# 496  {'Street': '2803 N Catalina Ave', 'Suburb': 'P...     Pilliga   NSW
# 497  {'Street': '22 Livingston Ave', 'Suburb': 'Rho...      Rhodes   NSW
# 498  {'Street': '403 Conn Valley Rd', 'Suburb': 'Ca...  Castletown    WA
# 499  {'Street': '5400 Market St', 'Suburb': 'Turill...      Turill   NSW
#
#      Post      Phone     Mobile                        Email         FullName  \
# 0    7315  381749123  458665290  rebbecca.didio@didio.com.au   Rebbecca Didio
# 1    4613  799973366  497622620     stevie.hallo@hotmail.com     Stevie Hallo
# 2    6215  855589019  427885282    mariko_stayer@hotmail.com    Mariko Stayer
# 3    2640  260444682  443795912   gerardo_woodka@hotmail.com   Gerardo Woodka
# 4    1595  214556085  453666885         mayra.bena@gmail.com       Mayra Bena
# ..    ...        ...        ...                          ...              ...
# 495  4490  785615894  475337188            miles@hotmail.com    Miles Feldner
# 496  2388  269959902  464594316     julio.mikel@mikel.net.au      Julio Mikel
# 497  2138  237387508  443448467      aide.ghera@ghera.com.au       Aide Ghera
# 498  6450  837733770  454135614       noelia@brackett.net.au  Noelia Brackett
# 499  2850  278625151  454434110       lenora@delacruz.net.au  Lenora Delacruz
#
#       Age SalaryBucket
# 0    34.0            C
# 1    38.0            C
# 2    30.0            C
# 3    31.0            C
# 4    50.0            C
# ..    ...          ...
# 495  30.0            C
# 496  27.0            C
# 497  22.0            C
# 498  54.0            C
# 499   NaN            C
#
# [500 rows x 13 columns]
# Saving data to JSON file...
# Data successfully saved to '/Users/deep/Assignemnt-20240524-NSW-Sydney/data/output-data.json'
